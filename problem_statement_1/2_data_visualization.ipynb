# %%
import matplotlib.pyplot as plt
#if we want to access the data from api then we can do by this.
#import requests
#response = requests.get("https://api.example.com/students/scores")
#students = response.json()

# %%
#assuming the output for api as follow
students = [
    {"name": "Alice", "score": 85},
    {"name": "Bob", "score": 90},
    {"name": "Charlie", "score": 78},
    {"name": "Diana", "score": 92},
    {"name": "Ethan", "score": 88},
]

# %%
score = [student['score'] for student in students]
average = sum(score)/ len(score)
names = [student['name'] for student in students]

# %%
plt.bar(names, score)
plt.title("Student Test Scores")
plt.xlabel("Students")
plt.ylabel("Scores")
# Out:
# Text(0, 0.5, 'Scores')
